# %%
# %pip install ultralytics
#hacer pip install en consola si no funciona
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 21.0 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="plI7oPaRBDHqCSFf42SX")
project = rf.workspace("proyec-bsyrh").project("xerosis-cylia")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 66.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 100.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Xerosis-2 in yolov11:: 100%|██████████| 1260/1260 [00:00<00:00, 7691.98it/s]

# %%
from ultralytics import YOLO

# Cargar modelo base
model = YOLO('/content/Xerosis-2/last (1).pt')

# Entrenar
model.train(data='/content/Xerosis-2/data.yaml', epochs=200, imgsz=640, batch=16, resume = True, save = True)
# Out:
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.8.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
import torch
print(torch.__version__)
print(torch.version.cuda)
print(torch.cuda.is_available())
# Out:
# 2.9.0+cpu
# None
# False

# %%
from ultralytics import YOLO
model = YOLO("runs\\detect\\train19\\weights\\last.pt")

metrics = model.val()
metrics.box.map
metrics.box.map50
metrics.box.map75
metrics.box.maps

# %%
from ultralytics import YOLO

# Load a pretrained YOLO11n model
model = YOLO("./lesions.pt")

# Define path to the image file
source = "../images/brazo.png"

# Run inference on the source
results = model(source)  # list of Results objects
